# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrakar-shubham/Be-Zen-Data-Engineer-Assignment/blob/main/Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %% [markdown]
# This database includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks.
#
# To understand pattern of terrorist activities we need to the perform analysis in the following manner:
#
# 1. **Data Importing** : Importing the data into the dataframe
# 2. **Understanding the problem** : We will explore and analysis the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Imporing data .csv file

# %%
file_path ='/content/drive/MyDrive/Capstone projects/Global Terrorism Analysis/Global Terrorism Analysis/Global Terrorism Data.csv'

#creating dataframe from csv file

df =  pd.read_csv(file_path,encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# settings to display all columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# #Data checking

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1        0.0          NaN             NaN
# 1     NaN      1      1      1        0.0          NaN             NaN
# 2     NaN      1      1      1        0.0          NaN             NaN
# 3     NaN      1      1      1        0.0          NaN             NaN
# 4     NaN      1      1      1       -9.0          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN         0         NaN            NaN        NaN         NaN
# 1       NaN         0         NaN            NaN        NaN         NaN
# 2       NaN         0         NaN            NaN        NaN         NaN
# 3       NaN         1         NaN            NaN        NaN         NaN
# 4       NaN         1         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS        0         0         0        0     NaN
# 1     PGIS        0         1         1        1     NaN
# 2     PGIS       -9        -9         1        1     NaN
# 3     PGIS       -9        -9         1        1     NaN
# 4     PGIS       -9        -9         1        1     NaN

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
# list of necessary columns

necessary_columns = ['iyear', 'imonth', 'iday','country', 'country_txt','region_txt','city',
                     'latitude', 'longitude', 'attacktype1_txt','targtype1_txt',
                     'targsubtype1_txt','target1','weaptype1_txt','nkill','nwound','success']

# %% [markdown]
# #Feature engineering

# %%
# keeping only necessary columns
df = df[necessary_columns]

# %%
df.head()
# Out:
#    iyear  imonth  iday  country         country_txt  \
# 0   1970       7     2       58  Dominican Republic
# 1   1970       0     0      130              Mexico
# 2   1970       1     0      160         Philippines
# 3   1970       1     0       78              Greece
# 4   1970       1     0      101               Japan
#
#                     region_txt           city   latitude   longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                     targsubtype1_txt                  target1  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weaptype1_txt  nkill  nwound  success
# 0       Unknown    1.0     0.0        1
# 1       Unknown    0.0     0.0        1
# 2       Unknown    1.0     0.0        1
# 3    Explosives    NaN     NaN        1
# 4    Incendiary    NaN     NaN        1

# %%
# renaming columns

rename_dict ={'iyear' : 'year','imonth':'month','iday':'day','country_txt' : 'country_name','region_txt':'region_name','attacktype1_txt': 'attack_type','targtype1_txt': 'target_type', 'targsubtype1_txt':'targ_subtype','target1':'target_name','weaptype1_txt':'weapon_type'}


df = df.rename(columns=rename_dict)

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city   latitude   longitude                     attack_type  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#                    target_type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success
# 0     Unknown    1.0     0.0        1
# 1     Unknown    0.0     0.0        1
# 2     Unknown    1.0     0.0        1
# 3  Explosives    NaN     NaN        1
# 4  Incendiary    NaN     NaN        1

# %% [markdown]
# Handling duplicated rows

# %%
#check for duplicated rows

len(df[df.duplicated()])
# Out:
# 10603

# %%
#removing duplicated rows

df=df[~df.duplicated()]

# %%
for col in df.columns:
  len_na = df[col].isna().sum()
  print(f'no of null value in {col} is = {round((len_na/len(df))*100,2)} percent null_value')
# Out:
# no of null value in year is = 0.0 percent null_value
# no of null value in month is = 0.0 percent null_value
# no of null value in day is = 0.0 percent null_value
# no of null value in country is = 0.0 percent null_value
# no of null value in country_name is = 0.0 percent null_value
# no of null value in region_name is = 0.0 percent null_value
# no of null value in city is = 0.25 percent null_value
# no of null value in latitude is = 2.34 percent null_value
# no of null value in longitude is = 2.34 percent null_value
# no of null value in attack_type is = 0.0 percent null_value
# no of null value in target_type is = 0.0 percent null_value
# no of null value in targ_subtype is = 5.43 percent null_value
# no of null value in target_name is = 0.32 percent null_value
# no of null value in weapon_type is = 0.0 percent null_value
# no of null value in nkill is = 5.47 percent null_value
# no of null value in nwound is = 8.86 percent null_value
# no of null value in success is = 0.0 percent null_value

# %%
#Dealing with the nan values 
df["city"].fillna("Unknown", inplace = True)
df["nkill"].fillna(0, inplace = True)
df["latitude"].fillna(0, inplace = True)
df["longitude"].fillna(0, inplace = True)
df["targ_subtype"].fillna("Unknown", inplace = True)
df["target_name"].fillna("Unknown", inplace = True)
df["nwound"].fillna(0, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Checking the null value in the features
df.isnull().sum()
# Out:
# year            0
# month           0
# day             0
# country         0
# country_name    0
# region_name     0
# city            0
# latitude        0
# longitude       0
# attack_type     0
# target_type     0
# targ_subtype    0
# target_name     0
# weapon_type     0
# nkill           0
# nwound          0
# success         0
# dtype: int64

# %%
def get_location(lat,long):
  '''get latitude and longitude return tuple of latitude and longitude'''
  return (lat,long)

# %%
# created new column containing total number of affected people

df['no_of_affected_people'] =df['nkill'] +df['nwound']


#create new column location using latitude and longitude

df['location']=df.apply(lambda x: get_location(x['latitude'],x['longitude']),axis =1)

# %%
df.head()

# %%
df.drop(columns=['latitude','longitude'],inplace = True)

# %%
df.head()

# %% [markdown]
# #EDA on Global Terrorism Database

# %%
#Distribution of Global terrorism across years

plt.figure(figsize=(24,12))

sns.displot(data = df,x ="year")
plt.ylabel("Distribution of  no. of attacks")
plt.title("Title: distribution of attack per year")
# Out:
# Text(0.5, 1.0, 'Title: distribution of attack per year')

# %%
#visualising attack per year with countplot

plt.figure(figsize=(18,12))
sns.countplot(data = df,x ="year")
plt.xticks(rotation=90)
plt.ylabel("No of attacks")
plt.title("Title: No. of attack per year")
# Out:
# Text(0.5, 1.0, 'Title: No. of attack per year')

# %%
df.groupby(['year',"country_name"]).size()
# Out:
# year  country_name
# 1970  Argentina                    21
#       Australia                     1
#       Belgium                       1
#       Bolivia                       1
#       Brazil                        6
#                                  ...
# 2017  Vietnam                       2
#       West Bank and Gaza Strip     83
#       Yemen                       221
#       Zambia                        2
#       Zimbabwe                      3
# Length: 3762, dtype: int64

# %% [markdown]
# #Share of terrorist activity country wise from 1970 to 2017

# %%
import numpy as np

# %%
year_country_terrorism_df = pd.DataFrame(df.groupby(["country_name"]).size().reset_index().rename(columns = {0:'no_of_terrorist_activity'}).sort_values(by='no_of_terrorist_activity',ascending = False))

# %%
year_country_terrorism_df
# Out:
#             country_name  no_of_terrorist_activity
# 84                  Iraq                     23105
# 134             Pakistan                     13721
# 0            Afghanistan                     12473
# 80                 India                     11540
# 35              Colombia                      7495
# ..                   ...                       ...
# 3                Andorra                         1
# 5    Antigua and Barbuda                         1
# 82         International                         1
# 169            St. Lucia                         1
# 163        South Vietnam                         1
#
# [205 rows x 2 columns]

# %%
year_country_terrorism_df['no_of_terrorist_activity'].describe([0.2,0.75,0.80,0.95,0.99])
# Out:
# count      205.000000
# mean       834.575610
# std       2439.727721
# min          1.000000
# 20%          8.000000
# 50%         63.000000
# 75%        346.000000
# 80%        671.400000
# 95%       4011.400000
# 99%      12435.680000
# max      23105.000000
# Name: no_of_terrorist_activity, dtype: float64

# %%
top_year_country_terrorism_df = year_country_terrorism_df[year_country_terrorism_df['no_of_terrorist_activity'].values >= 4000]
bottom_year_country_terrorism_df = year_country_terrorism_df[year_country_terrorism_df['no_of_terrorist_activity'].values < 4000]

# %%
total_sum_others = bottom_year_country_terrorism_df['no_of_terrorist_activity'].sum()
data = [['others',total_sum_others]]
other_df = pd.DataFrame(data,columns = ['country_name','no_of_terrorist_activity'])

# %%
year_country_terrorism_df = pd.concat([top_year_country_terrorism_df,other_df])

# %%
year_country_terrorism_df
# Out:
#        country_name  no_of_terrorist_activity
# 84             Iraq                     23105
# 134        Pakistan                     13721
# 0       Afghanistan                     12473
# 80            India                     11540
# 35         Colombia                      7495
# 140     Philippines                      6766
# 139            Peru                      5052
# 188  United Kingdom                      4988
# 52      El Salvador                      4303
# 159         Somalia                      4087
# 183          Turkey                      4070
# 0            others                     73488

# %%
#colors = sns.color_palette('bright')[:40]
fig = plt.figure(figsize =(15, 10))
plt.pie(list(year_country_terrorism_df['no_of_terrorist_activity'].values),labels = list(year_country_terrorism_df['country_name'].values),autopct='%1.0f%%')
plt.show()

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %% [markdown]
# # Most targeted city from 1970 to 2017

# %%
df['city'].value_counts()
# Out:
# Unknown            8547
# Baghdad            7428
# Karachi            2175
# Mosul              2053
# Belfast            2014
#                    ...
# Khoja Sabz Posh       1
# Chandpara             1
# Ruanda                1
# Verkhniy Baksan       1
# Kubentog              1
# Name: city, Length: 36674, dtype: int64

# %%
targeted_city = pd.DataFrame(df.groupby("city").size().sort_values(ascending = False).reset_index().rename(columns = {0:'count'}))

# %%
top_ten_targeted_city = targeted_city[1:11]
top_ten_targeted_city
# Out:
#             city  count
# 1        Baghdad   7428
# 2        Karachi   2175
# 3          Mosul   2053
# 4        Belfast   2014
# 5           Lima   1742
# 6      Mogadishu   1548
# 7       Santiago   1347
# 8   San Salvador   1242
# 9       Istanbul    913
# 10        Kirkuk    912

# %%
#visualize top ten targeted city
fig = plt.figure(figsize =(12, 8))
sns.barplot(data = top_ten_targeted_city,x='city',y='count')
plt.title("Top 10 targeted city from 1970 to 2017")
plt.xlabel('Name of city')
plt.ylabel('Title : Total no of terrorist activity in the city')
# Out:
# Text(0, 0.5, 'Title : Total no of terrorist activity in the city')

# %% [markdown]
# # Mode of Attack by used by terrorism

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
attack_pattern_df = pd.DataFrame(df['attack_type'].value_counts().reset_index().rename(columns= {'index':'type_of_attack','attack_type':'no_of_attack'}))

# %%
attack_pattern_df
# Out:
#                         type_of_attack  no_of_attack
# 0                    Bombing/Explosion         81356
# 1                        Armed Assault         41246
# 2                        Assassination         18885
# 3          Hostage Taking (Kidnapping)         10952
# 4       Facility/Infrastructure Attack          9233
# 5                              Unknown          6898
# 6  Hostage Taking (Barricade Incident)           938
# 7                      Unarmed Assault           930
# 8                            Hijacking           650

# %%
# Visualize mode of attack by used by terrorism

fig = plt.figure(figsize =(15, 10))
plt.pie(attack_pattern_df['no_of_attack'],labels = attack_pattern_df['type_of_attack'],autopct='%1.0f%%')
plt.title('Title : Mode of attack by used by terrorism')
plt.show()

# %% [markdown]
# # Type of institutinal targets targeted by terrorist over span of 1970 to 2017

# %%
institutional_target_df = pd.DataFrame(df['target_type'].value_counts().reset_index().rename(columns= {'index':'type_of_target','target_type':'no_of_target'}))
institutional_target_df
# Out:
#                     type_of_target  no_of_target
# 0      Private Citizens & Property         41037
# 1                         Military         27447
# 2                           Police         23756
# 3             Government (General)         20447
# 4                         Business         18861
# 5                   Transportation          6095
# 6                          Unknown          5065
# 7   Religious Figures/Institutions          4267
# 8          Educational Institution          4143
# 9                        Utilities          4139
# 10         Government (Diplomatic)          3511
# 11    Terrorists/Non-State Militia          2992
# 12             Journalists & Media          2889
# 13         Violent Political Party          1799
# 14             Airports & Aircraft          1320
# 15                             NGO           956
# 16               Telecommunication           908
# 17                        Tourists           431
# 18                        Maritime           339
# 19            Food or Water Supply           297
# 20                Abortion Related           257
# 21                           Other           132

# %%
top_target_df = institutional_target_df[:14]
top_target_df
# Out:
#                     type_of_target  no_of_target
# 0      Private Citizens & Property         41037
# 1                         Military         27447
# 2                           Police         23756
# 3             Government (General)         20447
# 4                         Business         18861
# 5                   Transportation          6095
# 6                          Unknown          5065
# 7   Religious Figures/Institutions          4267
# 8          Educational Institution          4143
# 9                        Utilities          4139
# 10         Government (Diplomatic)          3511
# 11    Terrorists/Non-State Militia          2992
# 12             Journalists & Media          2889
# 13         Violent Political Party          1799

# %%
bottom_target_df = institutional_target_df[14:]
bottom_target_df
# Out:
#           type_of_target  no_of_target
# 14   Airports & Aircraft          1320
# 15                   NGO           956
# 16     Telecommunication           908
# 17              Tourists           431
# 18              Maritime           339
# 19  Food or Water Supply           297
# 20      Abortion Related           257
# 21                 Other           132

# %%
total_sum_other_target = bottom_target_df['no_of_target'].sum()
data_other_target = [['others',total_sum_other_target]]
other_target_df = pd.DataFrame(data,columns = ['type_of_target','no_of_target'])

institutional_target_df = pd.concat([top_target_df,other_target_df])

# %%
# List of targets of terrorist
institutional_target_df
# Out:
#                     type_of_target  no_of_target
# 0      Private Citizens & Property         41037
# 1                         Military         27447
# 2                           Police         23756
# 3             Government (General)         20447
# 4                         Business         18861
# 5                   Transportation          6095
# 6                          Unknown          5065
# 7   Religious Figures/Institutions          4267
# 8          Educational Institution          4143
# 9                        Utilities          4139
# 10         Government (Diplomatic)          3511
# 11    Terrorists/Non-State Militia          2992
# 12             Journalists & Media          2889
# 13         Violent Political Party          1799
# 0                           others         73488

# %%
# Visualize mode of attack by used by terrorism

fig = plt.figure(figsize =(35, 15))
plt.pie(institutional_target_df['no_of_target'],labels = institutional_target_df['type_of_target'],autopct='%1.0f%%')
plt.title('Title : Share of institutinal targets targeted by terrorist over span of 1970 to 2017')
plt.show()

# %% [markdown]
# # Subtargets targeted by terrorists

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
df['targ_subtype'].value_counts()
# Out:
# Unnamed Civilian/Unspecified                               11143
# Police Security Forces/Officers                            10820
# Unknown                                                     9285
# Military Unit/Patrol/Convoy                                 8193
# Military Personnel (soldiers, troops, officers, forces)     7787
#                                                            ...
# Multiple Telecommunication Targets                            30
# Fire Fighter/Truck                                            25
# Oil Tanker                                                    19
# Personnel                                                     19
# Internet Infrastructure                                       12
# Name: targ_subtype, Length: 113, dtype: int64

# %%
# Creation of dataframe with group of type of subtarget and its no of times it was targeted

sub_target_df = pd.DataFrame(df['targ_subtype'].value_counts().reset_index().rename(columns= {'index':'type_of_sub_target','target_type':'no_of_target'}))
sub_target_df
# Out:
#                                     type_of_sub_target  targ_subtype
# 0                         Unnamed Civilian/Unspecified         11143
# 1                      Police Security Forces/Officers         10820
# 2                                              Unknown          9285
# 3                          Military Unit/Patrol/Convoy          8193
# 4    Military Personnel (soldiers, troops, officers...          7787
# ..                                                 ...           ...
# 108                 Multiple Telecommunication Targets            30
# 109                                 Fire Fighter/Truck            25
# 110                                         Oil Tanker            19
# 111                                          Personnel            19
# 112                            Internet Infrastructure            12
#
# [113 rows x 2 columns]

# %%
# This dataframe consist of top 20 subtarget

top_sub_target_df = sub_target_df[:20]
top_sub_target_df
# Out:
#                                    type_of_sub_target  targ_subtype
# 0                        Unnamed Civilian/Unspecified         11143
# 1                     Police Security Forces/Officers         10820
# 2                                             Unknown          9285
# 3                         Military Unit/Patrol/Convoy          8193
# 4   Military Personnel (soldiers, troops, officers...          7787
# 5   Government Personnel (excluding police, military)          6565
# 6                            Village/City/Town/Suburb          6063
# 7   Politician or Political Party Movement/Meeting...          6055
# 8     Police Building (headquarters, station, school)          5640
# 9      Police Patrol (including vehicles and convoys)          5079
# 10      Military Barracks/Base/Headquarters/Checkpost          5079
# 11                Government Building/Facility/Office          4417
# 12                              Retail/Grocery/Bakery          3838
# 13             School/University/Educational Building          2835
# 14                           Marketplace/Plaza/Square          2811
# 15                            Vehicles/Transportation          2576
# 16                                     Named Civilian          2549
# 17                                   Place of Worship          2472
# 18            Laborer (General)/Occupation Identified          2453
# 19                                      Bank/Commerce          2422

# %%
# visualization top 20 subtarget targeted by terrorist in span of 1970 to 2017 using bar plot

fig = plt.figure(figsize =(10, 8))
sns.barplot(data = top_sub_target_df, x='type_of_sub_target',y='targ_subtype')
plt.xticks(rotation=90)
plt.xlabel("Type of sub-target target by terrorists")
plt.ylabel("No of sub-target target by terrorists")
plt.title("Title: Sub-target targeted by terrorist in span of 1970 to 2017")
# Out:
# Text(0.5, 1.0, 'Title: Sub-target targeted by terrorist in span of 1970 to 2017')

# %% [markdown]
# #Name of Top 20 target of terrorist

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
df['target_name'].value_counts()
# Out:
# Civilians                  6234
# Unknown                    5878
# Soldiers                   3048
# Patrol                     2925
# Checkpoint                 2760
#                            ...
# Mayor Sanit Lokasemsant       1
# John Dignam                   1
# Aidan Starrs                  1
# Gregory Burns                 1
# Hmeymim Air Base              1
# Name: target_name, Length: 86006, dtype: int64

# %%
# Creation of dataframe with group of type of subtarget and its no of times it was targeted

name_of_target_df = pd.DataFrame(df['target_name'].value_counts().reset_index().rename(columns= {'index':'name_of_target','target_name':'no_of_times_targeted'}))

# %%
name_of_target_df
# Out:
#                 name_of_target  no_of_times_targeted
# 0                    Civilians                  6234
# 1                      Unknown                  5878
# 2                     Soldiers                  3048
# 3                       Patrol                  2925
# 4                   Checkpoint                  2760
# ...                        ...                   ...
# 86001  Mayor Sanit Lokasemsant                     1
# 86002              John Dignam                     1
# 86003             Aidan Starrs                     1
# 86004            Gregory Burns                     1
# 86005         Hmeymim Air Base                     1
#
# [86006 rows x 2 columns]

# %%
#top 20 name of target targeted by terrorist

top20_name_of_target_df=name_of_target_df[:20]

# %%
# visualization Name of top 20 target targeted by terrorist in span of 1970 to 2017 using bar plot

fig = plt.figure(figsize =(10, 8))
sns.barplot(data = top20_name_of_target_df, x='name_of_target',y='no_of_times_targeted')
plt.xticks(rotation=90)
plt.xlabel("Name of target targeted by terrorists")
plt.ylabel("No of times targeted by terrorists")
plt.title("Title: Name of target targeted by terrorist in span of 1970 to 2017")
# Out:
# Text(0.5, 1.0, 'Title: Name of target targeted by terrorist in span of 1970 to 2017')

# %% [markdown]
# #Type of weapon used by terrorist

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
df['weapon_type'].value_counts()
# Out:
# Explosives                                                                     85547
# Firearms                                                                       57303
# Unknown                                                                        14456
# Incendiary                                                                      9472
# Melee                                                                           3530
# Chemical                                                                         314
# Sabotage Equipment                                                               136
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            112
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: weapon_type, dtype: int64

# %%
# Creation of dataframe with type of weapon and its no of times it was used

weapon_df = pd.DataFrame(df['weapon_type'].value_counts().reset_index().rename(columns= {'index':'type_of_weapon','weapon_type':'no_of_times_weapon_used'}))
weapon_df
# Out:
#                                        type_of_weapon  no_of_times_weapon_used
# 0                                          Explosives                    85547
# 1                                            Firearms                    57303
# 2                                             Unknown                    14456
# 3                                          Incendiary                     9472
# 4                                               Melee                     3530
# 5                                            Chemical                      314
# 6                                  Sabotage Equipment                      136
# 7   Vehicle (not to include vehicle-borne explosiv...                      136
# 8                                               Other                      112
# 9                                          Biological                       35
# 10                                       Fake Weapons                       33
# 11                                       Radiological                       14

# %%
# Visualize type of weapon by used by terrorist

fig = plt.figure(figsize =(7, 5))
sns.barplot(data = weapon_df,x=weapon_df['no_of_times_weapon_used'],y = weapon_df['type_of_weapon'])
plt.title('Title : Share of weapons used by terrorist over span of 1970 to 2017')
plt.xlabel('No of times weapon used')
plt.ylabel('Type of weapon')
plt.show()

# %% [markdown]
# #Successful terrorist attacks

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
#visualising successful attack each year with countplot

plt.figure(figsize=(18,12))
sns.countplot(data = df,x ="year",hue = "success")
plt.xticks(rotation=90)
plt.ylabel("No of attacks")
plt.title("Title: No. of attack per year")
# Out:
# Text(0.5, 1.0, 'Title: No. of attack per year')

# %% [markdown]
# #No of identified kills each year

# %%
df.groupby('year')['nkill'].sum()
# Out:
# year
# 1970      174.0
# 1971      173.0
# 1972      565.0
# 1973      370.0
# 1974      539.0
# 1975      616.0
# 1976      674.0
# 1977      456.0
# 1978     1456.0
# 1979     2079.0
# 1980     4390.0
# 1981     4846.0
# 1982     5136.0
# 1983     9433.0
# 1984    10337.0
# 1985     6985.0
# 1986     4931.0
# 1987     6115.0
# 1988     7197.0
# 1989     8114.0
# 1990     6988.0
# 1991     8390.0
# 1992     9631.0
# 1994     7615.0
# 1995     5862.0
# 1996     6827.0
# 1997    10116.0
# 1998     4656.0
# 1999     3392.0
# 2000     4403.0
# 2001     7720.0
# 2002     4701.0
# 2003     3313.0
# 2004     5741.0
# 2005     6317.0
# 2006     9362.0
# 2007    12774.0
# 2008     9146.0
# 2009     9273.0
# 2010     7806.0
# 2011     8181.0
# 2012    15310.0
# 2013    22087.0
# 2014    44179.0
# 2015    38029.0
# 2016    34212.0
# 2017    26173.0
# Name: nkill, dtype: float64

# %%
year_kills = pd.DataFrame(df.groupby('year')['nkill'].sum().reset_index().rename(columns = {'nkill':'no_of_kills'}))

# %%
year_kills
# Out:
#     year  no_of_kills
# 0   1970        174.0
# 1   1971        173.0
# 2   1972        565.0
# 3   1973        370.0
# 4   1974        539.0
# 5   1975        616.0
# 6   1976        674.0
# 7   1977        456.0
# 8   1978       1456.0
# 9   1979       2079.0
# 10  1980       4390.0
# 11  1981       4846.0
# 12  1982       5136.0
# 13  1983       9433.0
# 14  1984      10337.0
# 15  1985       6985.0
# 16  1986       4931.0
# 17  1987       6115.0
# 18  1988       7197.0
# 19  1989       8114.0
# 20  1990       6988.0
# 21  1991       8390.0
# 22  1992       9631.0
# 23  1994       7615.0
# 24  1995       5862.0
# 25  1996       6827.0
# 26  1997      10116.0
# 27  1998       4656.0
# 28  1999       3392.0
# 29  2000       4403.0
# 30  2001       7720.0
# 31  2002       4701.0
# 32  2003       3313.0
# 33  2004       5741.0
# 34  2005       6317.0
# 35  2006       9362.0
# 36  2007      12774.0
# 37  2008       9146.0
# 38  2009       9273.0
# 39  2010       7806.0
# 40  2011       8181.0
# 41  2012      15310.0
# 42  2013      22087.0
# 43  2014      44179.0
# 44  2015      38029.0
# 45  2016      34212.0
# 46  2017      26173.0

# %%
#visualising no of kills each year with barplot

plt.figure(figsize=(18,12))
sns.barplot(data = year_kills,x ="year",y='no_of_kills')
plt.xticks(rotation=90)
plt.ylabel("No of kills")
plt.title("Title: No. of kills each year in span of 1970 to 2017")
# Out:
# Text(0.5, 1.0, 'Title: No. of kills each year in span of 1970 to 2017')

# %% [markdown]
# #No of identified wounded peoples

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171088 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   171088 non-null  int64
#  1   month                  171088 non-null  int64
#  2   day                    171088 non-null  int64
#  3   country                171088 non-null  int64
#  4   country_name           171088 non-null  object
#  5   region_name            171088 non-null  object
#  6   city                   171088 non-null  object
#  7   attack_type            171088 non-null  object
#  8   target_type            171088 non-null  object
#  9   targ_subtype           171088 non-null  object
#  10  target_name            171088 non-null  object
#  11  weapon_type            171088 non-null  object
#  12  nkill                  171088 non-null  float64
#  13  nwound                 171088 non-null  float64
#  14  success                171088 non-null  int64
#  15  no_of_affected_people  171088 non-null  float64
#  16  location               171088 non-null  object
# dtypes: float64(3), int64(5), object(9)
# memory usage: 27.5+ MB

# %%
year_wounded = pd.DataFrame(df.groupby('year')['nwound'].sum().reset_index().rename(columns = {'nwound':'no_of_wounded'}))
year_wounded
# Out:
#     year  no_of_wounded
# 0   1970          212.0
# 1   1971           82.0
# 2   1972          409.0
# 3   1973          495.0
# 4   1974          865.0
# 5   1975          617.0
# 6   1976          755.0
# 7   1977          507.0
# 8   1978         1590.0
# 9   1979         2501.0
# 10  1980         3633.0
# 11  1981         3313.0
# 12  1982         3337.0
# 13  1983         4022.0
# 14  1984         5261.0
# 15  1985         5102.0
# 16  1986         5717.0
# 17  1987         5643.0
# 18  1988         6948.0
# 19  1989         5521.0
# 20  1990         6128.0
# 21  1991         7564.0
# 22  1992         9866.0
# 23  1994         7488.0
# 24  1995        14227.0
# 25  1996        10537.0
# 26  1997         8173.0
# 27  1998         8100.0
# 28  1999         5341.0
# 29  2000         5868.0
# 30  2001        22762.0
# 31  2002         6929.0
# 32  2003         7384.0
# 33  2004        12019.0
# 34  2005        12746.0
# 35  2006        15521.0
# 36  2007        22456.0
# 37  2008        18928.0
# 38  2009        19119.0
# 39  2010        15860.0
# 40  2011        14499.0
# 41  2012        25232.0
# 42  2013        37211.0
# 43  2014        40771.0
# 44  2015        42971.0
# 45  2016        39137.0
# 46  2017        24745.0

# %%
#visualising no of kills each year with barplot

plt.figure(figsize=(18,12))
sns.barplot(data = year_wounded,x ="year",y='no_of_wounded')
plt.xticks(rotation=90)
plt.ylabel("No of wouned peoples")
plt.title("Title: No. of identified wounded people each year in span of 1970 to 2017")
# Out:
# Text(0.5, 1.0, 'Title: No. of identified wounded people each year in span of 1970 to 2017')

# %% [markdown]
# # Most prominent type of attack in a country in span of 1970 to 2017

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
df.groupby(['country_name','attack_type'])['attack_type'].count()
# Out:
# country_name  attack_type
# Afghanistan   Armed Assault                          2795
#               Assassination                           954
#               Bombing/Explosion                      6203
#               Facility/Infrastructure Attack          288
#               Hijacking                                16
#                                                      ...
# Zimbabwe      Facility/Infrastructure Attack            6
#               Hostage Taking (Barricade Incident)       2
#               Hostage Taking (Kidnapping)               4
#               Unarmed Assault                           2
#               Unknown                                   5
# Name: attack_type, Length: 1279, dtype: int64

# %%
#list of countries with most prominet mode of attack used by terrorist till 2017 in that country

country_attack_type = pd.DataFrame(df.groupby('country_name').agg({'attack_type': [pd.Series.mode],'weapon_type':[pd.Series.mode]}).reset_index())
country_attack_type
# Out:
#     country_name        attack_type weapon_type
#                                mode        mode
# 0    Afghanistan  Bombing/Explosion  Explosives
# 1        Albania  Bombing/Explosion  Explosives
# 2        Algeria  Bombing/Explosion  Explosives
# 3        Andorra      Armed Assault    Firearms
# 4         Angola      Armed Assault    Firearms
# ..           ...                ...         ...
# 200        Yemen  Bombing/Explosion  Explosives
# 201   Yugoslavia      Armed Assault    Firearms
# 202        Zaire      Armed Assault     Unknown
# 203       Zambia  Bombing/Explosion  Explosives
# 204     Zimbabwe  Bombing/Explosion  Explosives
#
# [205 rows x 3 columns]

# %%
# Type of attack mostly used in which country ?

attack_type_mode_country = pd.DataFrame(df.groupby('attack_type').agg({'country_name': [pd.Series.mode],'region_name':[pd.Series.mode]}).reset_index())
attack_type_mode_country
# Out:
#                            attack_type             country_name  \
#                                                            mode
# 0                        Armed Assault                 Pakistan
# 1                        Assassination           United Kingdom
# 2                    Bombing/Explosion                     Iraq
# 3       Facility/Infrastructure Attack                    India
# 4                            Hijacking                    Sudan
# 5  Hostage Taking (Barricade Incident)  [Colombia, El Salvador]
# 6          Hostage Taking (Kidnapping)                    India
# 7                      Unarmed Assault                    India
# 8                              Unknown              Afghanistan
#
#                   region_name
#                          mode
# 0                  South Asia
# 1  Middle East & North Africa
# 2  Middle East & North Africa
# 3              Western Europe
# 4  Middle East & North Africa
# 5               South America
# 6                  South Asia
# 7                  South Asia
# 8                  South Asia

# %% [markdown]
# #Type of target chosen mostly used for a country and region

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
# type of target chosen mostly used in specific country and region

target_type_mode_country = pd.DataFrame(df.groupby('target_type').agg({'country_name': [pd.Series.mode],'region_name':[pd.Series.mode]}).reset_index())
target_type_mode_country
# Out:
#                        target_type   country_name                 region_name
#                                              mode                        mode
# 0                 Abortion Related  United States               North America
# 1              Airports & Aircraft       Colombia              Western Europe
# 2                         Business           Iraq  Middle East & North Africa
# 3          Educational Institution       Pakistan                  South Asia
# 4             Food or Water Supply           Peru                  South Asia
# 5          Government (Diplomatic)        Lebanon  Middle East & North Africa
# 6             Government (General)           Iraq                  South Asia
# 7              Journalists & Media       Colombia  Middle East & North Africa
# 8                         Maritime    Philippines              Southeast Asia
# 9                         Military           Iraq  Middle East & North Africa
# 10                             NGO    Afghanistan                  South Asia
# 11                           Other           Iraq  Middle East & North Africa
# 12                          Police           Iraq                  South Asia
# 13     Private Citizens & Property           Iraq  Middle East & North Africa
# 14  Religious Figures/Institutions           Iraq  Middle East & North Africa
# 15               Telecommunication          India                  South Asia
# 16    Terrorists/Non-State Militia           Iraq  Middle East & North Africa
# 17                        Tourists          India  Middle East & North Africa
# 18                  Transportation          India                  South Asia
# 19                         Unknown           Iraq                  South Asia
# 20                       Utilities       Colombia               South America
# 21         Violent Political Party       Pakistan                  South Asia

# %% [markdown]
# #Type of weapon mostly used in specific country

# %%
df.head()
# Out:
#    year  month  day  country        country_name                  region_name  \
# 0  1970      7    2       58  Dominican Republic  Central America & Caribbean
# 1  1970      0    0      130              Mexico                North America
# 2  1970      1    0      160         Philippines               Southeast Asia
# 3  1970      1    0       78              Greece               Western Europe
# 4  1970      1    0      101               Japan                    East Asia
#
#             city                     attack_type                  target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                         targ_subtype              target_name  \
# 0                                     Named Civilian             Julio Guzman
# 1  Diplomatic Personnel (outside of embassy, cons...  Nadine Chaval, daughter
# 2                    Radio Journalist/Staff/Facility                 Employee
# 3                                  Embassy/Consulate             U.S. Embassy
# 4                                  Embassy/Consulate           U.S. Consulate
#
#   weapon_type  nkill  nwound  success  no_of_affected_people  \
# 0     Unknown    1.0     0.0        1                    1.0
# 1     Unknown    0.0     0.0        1                    0.0
# 2     Unknown    1.0     0.0        1                    1.0
# 3  Explosives    0.0     0.0        1                    0.0
# 4  Incendiary    0.0     0.0        1                    0.0
#
#                   location
# 0  (18.456792, -69.951164)
# 1  (19.371887, -99.086624)
# 2  (15.478598, 120.599741)
# 3    (37.99749, 23.762728)
# 4  (33.580412, 130.396361)

# %%
# type of weapon chosen mostly used in specific country and region

weapon_type_mode_country = pd.DataFrame(df.groupby('weapon_type').agg({'country_name': [pd.Series.mode],'region_name':[pd.Series.mode]}).reset_index())
weapon_type_mode_country
# Out:
#                                           weapon_type  \
#
# 0                                          Biological
# 1                                            Chemical
# 2                                          Explosives
# 3                                        Fake Weapons
# 4                                            Firearms
# 5                                          Incendiary
# 6                                               Melee
# 7                                               Other
# 8                                        Radiological
# 9                                  Sabotage Equipment
# 10                                            Unknown
# 11  Vehicle (not to include vehicle-borne explosiv...
#
#                 country_name                                   region_name
#                         mode                                          mode
# 0              United States                                 North America
# 1                Afghanistan                                    South Asia
# 2                       Iraq                    Middle East & North Africa
# 3              United States  [Middle East & North Africa, Western Europe]
# 4                   Pakistan                                    South Asia
# 5              United States                                Western Europe
# 6                      India                    Middle East & North Africa
# 7              United States                    Middle East & North Africa
# 8                      Japan                                     East Asia
# 9                      India                                    South Asia
# 10               Afghanistan                                    South Asia
# 11  West Bank and Gaza Strip                    Middle East & North Africa

# %% [markdown]
# # City,region and mostly used type of attack

# %%
df1 =df.copy()

# %%
df1 = df1[~(df1['city']=='Unknown')]

# %%
# type of attack chosen mostly used in specific city

attack_type_mode_country = pd.DataFrame(df1.groupby('attack_type').agg({'city': [pd.Series.mode],'region_name':[pd.Series.mode]}).reset_index())
attack_type_mode_country
# Out:
#                            attack_type          city  \
#                                                 mode
# 0                        Armed Assault       Karachi
# 1                        Assassination       Belfast
# 2                    Bombing/Explosion       Baghdad
# 3       Facility/Infrastructure Attack        Athens
# 4                            Hijacking        Beirut
# 5  Hostage Taking (Barricade Incident)  San Salvador
# 6          Hostage Taking (Kidnapping)         Mosul
# 7                      Unarmed Assault     Jerusalem
# 8                              Unknown         Mosul
#
#                   region_name
#                          mode
# 0                  South Asia
# 1  Middle East & North Africa
# 2  Middle East & North Africa
# 3              Western Europe
# 4          Sub-Saharan Africa
# 5               South America
# 6                  South Asia
# 7                  South Asia
# 8                  South Asia

# %% [markdown]
# #Region wise no of people killed,wounded and total no of people affected in various years

# %%
# Region wise no of people killed visualisation via line plot
plt.figure(figsize=(13,8))
sns.lineplot(data = df,x='year',y='nkill',hue = 'region_name')

# %%
# Region wise no of people wounded visualisation via line plot

plt.figure(figsize=(13,15))
sns.lineplot(data = df,x='year',y='nwound',hue = 'region_name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171088 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   171088 non-null  int64
#  1   month                  171088 non-null  int64
#  2   day                    171088 non-null  int64
#  3   country                171088 non-null  int64
#  4   country_name           171088 non-null  object
#  5   region_name            171088 non-null  object
#  6   city                   171088 non-null  object
#  7   attack_type            171088 non-null  object
#  8   target_type            171088 non-null  object
#  9   targ_subtype           171088 non-null  object
#  10  target_name            171088 non-null  object
#  11  weapon_type            171088 non-null  object
#  12  nkill                  171088 non-null  float64
#  13  nwound                 171088 non-null  float64
#  14  success                171088 non-null  int64
#  15  no_of_affected_people  171088 non-null  float64
#  16  location               171088 non-null  object
# dtypes: float64(3), int64(5), object(9)
# memory usage: 27.5+ MB

# %%
# Region wise no of people affected visualisation via line plot

plt.figure(figsize=(13,15))
sns.lineplot(data = df,x='year',y='no_of_affected_people',hue = 'region_name')
